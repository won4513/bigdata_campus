# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
#자전거 이용률
data=pd.read_csv("C:/Users/guswn/OneDrive/바탕 화면/bike/자전거+이용률_20231029114635.csv",encoding="utf-8")

# %%
#이름 교체
data = pd.DataFrame(data.values[1:], columns=data.iloc[0])

# %%
data
# Out:
# 0   구분별(1)        구분별(2)  통학/통근  대중교통 환승  근거리 교통수단   레저용  이용하지 않음
# 0      서울시            소계    1.8      0.3       4.7   5.6     87.6
# 1       성별            남성    2.9      0.5       6.4   8.0     82.2
# 2       성별            여성    0.7      0.2       3.1   3.3     92.7
# 3      연령별           10대    8.6      0.2      10.8   7.1     73.2
# 4      연령별           20대    1.8      0.8      10.1   9.2     78.0
# 5      연령별           30대    1.6      0.3       3.5   8.3     86.2
# 6      연령별           40대    1.4      0.2       2.5   6.0     89.8
# 7      연령별           50대    1.3      0.1       1.8   4.4     92.4
# 8      연령별        60대 이상    1.4      0.2       4.3   1.8     92.3
# 9      학력별         중졸 이하    1.0      0.3       7.3   1.3     90.2
# 10     학력별         고졸 이하    2.8      0.2       3.6   2.8     90.7
# 11     학력별         대졸 이하    1.4      0.4       4.8   7.5     85.9
# 12     학력별        대학원 이상    2.7      0.7       5.9  16.3     74.4
# ...

# %%
numeric_columns = data.columns[2:]  # 숫자로 변환할 열 선택, 첫 번째 열은 제외
data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
#성별에 다른 분류
sex=data[data["구분별(1)"]=="성별"]
sex=sex.drop("구분별(1)",axis=1)

# %%
sex
# Out:
# 0 구분별(2)  통학/통근  대중교통 환승  근거리 교통수단  레저용  이용하지 않음
# 1     남성    2.9      0.5       6.4  8.0     82.2
# 2     여성    0.7      0.2       3.1  3.3     92.7

# %%
sex.plot.bar(x="구분별(2)",alpha=0.5,stacked=True, figsize=(20,5))
plt.title("성별 이용정보")
# Out:
# Text(0.5, 1.0, '성별 이용정보')

# %%
# 연령대에 다른 분류
age=data[data["구분별(1)"]=="연령별"]
age=age.drop("구분별(1)",axis=1)

# %%
age
# Out:
# 0  구분별(2)  통학/통근  대중교통 환승  근거리 교통수단  레저용  이용하지 않음
# 3     10대    8.6      0.2      10.8  7.1     73.2
# 4     20대    1.8      0.8      10.1  9.2     78.0
# 5     30대    1.6      0.3       3.5  8.3     86.2
# 6     40대    1.4      0.2       2.5  6.0     89.8
# 7     50대    1.3      0.1       1.8  4.4     92.4
# 8  60대 이상    1.4      0.2       4.3  1.8     92.3

# %%
age_10=age_10.drop("구분별(2)",axis=1)

# %%
age.plot.bar(x="구분별(2)",alpha=0.5,stacked=True, figsize=(20,5))
plt.title("나이대별 이용정보")
# Out:
# Text(0.5, 1.0, '나이대별 이용정보')

# %%
# 학력별 다른 분류
grade=data[data["구분별(1)"]=="연령별"]

# %%
# 지역에 다른 분류
income=data[data["구분별(1)"]=="소득별"]

# %%
income=income.drop("구분별(1)",axis=1)

# %%
income.plot.bar(x="구분별(2)",alpha=0.5,stacked=True, figsize=(20,5))
plt.title("소득별 이용 정보")
# Out:
# Text(0.5, 1.0, '소득별 이용 정보')

# %%
region=data[data["구분별(1)"]=="지역소분류별"]

# %%
region=region.drop("구분별(1)",axis=1)

# %%
region
# Out:
# 0  구분별(2)  통학/통근  대중교통 환승  근거리 교통수단   레저용  이용하지 않음
# 26    종로구    4.7      0.2       7.0   3.8     84.2
# 27     중구    1.6      0.1       2.8   2.0     93.5
# 28    용산구    1.6      0.4       1.3   6.5     90.2
# 29    성동구    1.4      0.0       2.2  10.0     86.3
# 30    광진구    4.2      0.2       3.2   5.0     87.4
# 31   동대문구    1.6      0.3       6.0   5.3     86.8
# 32    중랑구    0.9      0.3       0.6   3.9     94.3
# 33    성북구    3.6      0.1       4.4   4.5     87.4
# 34    강북구    0.8      0.3       5.2   2.6     91.1
# 35    도봉구    2.0      0.3      11.1   5.2     81.3
# 36    노원구    5.7      1.3      14.8   1.4     76.7
# 37    은평구    1.2      NaN       4.5   4.9     89.4
# 38   서대문구    1.3      0.0       2.9  10.3     85.4
# 39    마포구    1.4      0.0       3.4   5.2     89.9
# 40    양천구    0.2      NaN      11.7  10.4     77.7
# 41    강서구    1.2      0.2       2.0   5.0     91.6
# 42    구로구    0.8      0.8       4.1   4.1     90.3
# ...

# %%
region_sorted_1 = region.sort_values(by='통학/통근', ascending=False)
region_sorted_1.head(5)
region_sorted_1.tail(5)
# Out:
# 0  구분별(2)  통학/통근  대중교통 환승  근거리 교통수단   레저용  이용하지 않음
# 42    구로구    0.8      0.8       4.1   4.1     90.3
# 34    강북구    0.8      0.3       5.2   2.6     91.1
# 44   영등포구    0.6      0.1       3.6   5.3     90.4
# 43    금천구    0.5      0.3       4.1   5.1     90.1
# 40    양천구    0.2      NaN      11.7  10.4     77.7

# %%
#유일하게 na값 존재
region_drop = region.dropna()
region_sorted_2 = region_drop.sort_values(by='대중교통 환승', ascending=False)
region_sorted_2.head(5)
region_sorted_2.tail(5)
# Out:
# 0  구분별(2)  통학/통근  대중교통 환승  근거리 교통수단   레저용  이용하지 않음
# 33    성북구    3.6      0.1       4.4   4.5     87.4
# 39    마포구    1.4      0.0       3.4   5.2     89.9
# 48    강남구    1.0      0.0       3.7   9.4     85.9
# 29    성동구    1.4      0.0       2.2  10.0     86.3
# 38   서대문구    1.3      0.0       2.9  10.3     85.4

# %%
region_sorted_3 = region.sort_values(by='근거리 교통수단', ascending=False)
region_sorted_3.head(5)
region_sorted_3.tail(5)
# Out:
# 0  구분별(2)  통학/통근  대중교통 환승  근거리 교통수단   레저용  이용하지 않음
# 50    강동구    2.2      0.6       2.5   4.3     90.5
# 29    성동구    1.4      0.0       2.2  10.0     86.3
# 41    강서구    1.2      0.2       2.0   5.0     91.6
# 28    용산구    1.6      0.4       1.3   6.5     90.2
# 32    중랑구    0.9      0.3       0.6   3.9     94.3

# %%
region_sorted_4 = region.sort_values(by='레저용', ascending=False)
region_sorted_4.head(5)
region_sorted_4.tail(5)
# Out:
# 0  구분별(2)  통학/통근  대중교통 환승  근거리 교통수단   레저용  이용하지 않음
# 40    양천구    0.2      NaN      11.7  10.4     77.7
# 38   서대문구    1.3      0.0       2.9  10.3     85.4
# 29    성동구    1.4      0.0       2.2  10.0     86.3
# 48    강남구    1.0      0.0       3.7   9.4     85.9
# 46    관악구    0.9      0.4       3.1   7.8     87.8

# %%
region_sorted_5 = region.sort_values(by='이용하지 않음', ascending=False)
region_sorted_5.head(5)
region_sorted_5.tail(5)
# Out:
# 0  구분별(2)  통학/통근  대중교통 환승  근거리 교통수단   레저용  이용하지 않음
# 38   서대문구    1.3      0.0       2.9  10.3     85.4
# 26    종로구    4.7      0.2       7.0   3.8     84.2
# 35    도봉구    2.0      0.3      11.1   5.2     81.3
# 40    양천구    0.2      NaN      11.7  10.4     77.7
# 36    노원구    5.7      1.3      14.8   1.4     76.7
