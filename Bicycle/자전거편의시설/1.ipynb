# %%
pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gp

# %%
bic19 = gp.read_file('/Users/chaewon/Downloads/B408. 서울시 자전거 편의시설 공간데이터/2. 파일데이터/2019/TL_BCYCL_INFR_ST_2019.shp')
bic19.head()
# Out:
#     ID TGRP_CODE            ADDR_KOR     GPS_X    GPS_Y           TM_X  \
# 0  1.0         2  서울특별시 마포구 동교로8길 58  126.9058  37.5496  191671.765816
# 1  2.0         2   서울특별시 마포구 월드컵로 72  126.9105  37.5560  192087.771450
# 2  3.0         2   서울특별시 마포구 월드컵로 79  126.9108  37.5550  192121.325941
# 3  4.0         2    서울특별시 마포구 양화로 59  126.9150  37.5506  192487.677109
# 4  5.0         2    서울특별시 마포구 양화로 48  126.9148  37.5500  192473.387681
#
#             TM_Y                       geometry
# 0  550008.949706  POINT (191671.766 550008.950)
# 1  550723.195890  POINT (192087.771 550723.196)
# 2  550606.737354  POINT (192121.326 550606.737)
# 3  550126.707129  POINT (192487.677 550126.707)
# 4  550057.685460  POINT (192473.388 550057.685)

# %%
bic18 = gp.read_file('/Users/chaewon/Downloads/B408. 서울시 자전거 편의시설 공간데이터/2. 파일데이터/2016/자전거 인프라 현황/CP_BD_2016_14.shp')
bic18.head()
# Out:
#     ID TGRP_CODE                ADDR_KOR   GPS_X   GPS_Y          TM_X  \
# 0  1.0         5     서울특별시 양천구 신정동 314-7  3.7522  1.2686  188431.65921
# 1  2.0         5     서울특별시 양천구 신정동 322-4  3.7517  1.2686  187998.97115
# 2  3.0         5     서울특별시 양천구 신정동 324-4  3.7515  1.2685  187545.02325
# 3  4.0         5     서울특별시 동대문구 용두동 47-1  3.7574  1.2703  203353.39122
# 4  5.0         5  서울특별시 동대문구 답십리동 496-11  3.7567  1.2705  204565.96209
#
#            TM_Y                       geometry
# 0  547012.26573  POINT (188431.659 447012.266)
# 1  546461.48439  POINT (187998.971 446461.484)
# 2  546244.38404  POINT (187545.023 446244.384)
# 3  552785.79462  POINT (203353.391 452785.795)
# 4  552044.22862  POINT (204565.962 452044.229)

# %%
bic17 = gp.read_file('/Users/chaewon/Downloads/B408. 서울시 자전거 편의시설 공간데이터/2. 파일데이터/2017/자전거 인프라 현황/TL_BCYCL_INFR_ST_2017/TL_BCYCL_INFR_ST_2017.shp')
bic17.head()
# Out:
#      ID TGRP_CODE               ADDR_KOR   GPS_X   GPS_Y          TM_X  \
# 0  16.0         5    서울특별시 양천구 목동 406-34  3.7524  1.2687  188978.02435
# 1  25.0         5  서울특별시 동대문구 장안동 469-10  3.7561  1.2706  205683.19017
# 2  34.0         5        서울특별시 송파구 방이동 4  3.7516  1.2711  210249.33408
# 3  42.0         5       서울특별시 양천구 목동 915  3.7525  1.2687  189108.23508
# 4  50.0         5    서울특별시 송파구 오금동 165-1  3.7497  1.2713  212082.82735
#
#            TM_Y                       geometry
# 0  547258.99970  POINT (188978.024 547259.000)
# 1  551379.17061  POINT (205683.190 551379.171)
# 2  546289.62564  POINT (210249.334 546289.626)
# 3  547380.87939  POINT (189108.235 547380.879)
# 4  544216.59942  POINT (212082.827 544216.599)

# %%
bic16 = gp.read_file('/Users/chaewon/Downloads/B408. 서울시 자전거 편의시설 공간데이터/2. 파일데이터/2016/자전거 인프라 현황/CP_BD_2016_14.shp')
bic16.head()
# Out:
#     ID TGRP_CODE                ADDR_KOR   GPS_X   GPS_Y          TM_X  \
# 0  1.0         5     서울특별시 양천구 신정동 314-7  3.7522  1.2686  188431.65921
# 1  2.0         5     서울특별시 양천구 신정동 322-4  3.7517  1.2686  187998.97115
# 2  3.0         5     서울특별시 양천구 신정동 324-4  3.7515  1.2685  187545.02325
# 3  4.0         5     서울특별시 동대문구 용두동 47-1  3.7574  1.2703  203353.39122
# 4  5.0         5  서울특별시 동대문구 답십리동 496-11  3.7567  1.2705  204565.96209
#
#            TM_Y                       geometry
# 0  547012.26573  POINT (188431.659 447012.266)
# 1  546461.48439  POINT (187998.971 446461.484)
# 2  546244.38404  POINT (187545.023 446244.384)
# 3  552785.79462  POINT (203353.391 452785.795)
# 4  552044.22862  POINT (204565.962 452044.229)

# %%
bic19.plot()
# Out:
# <Axes: >

# %%
import pandas as pd

# %%
bike1 = pd.read_csv('/Users/chaewon/Desktop/서울빅캠/data/자전거도로 현황.csv',)
bike1
# Out:
#     지역별(1)  지역별(2)  지역별(3)     2018   2018.1    2018.2    2018.3       2018.4  \
# 0   지역별(1)  지역별(2)  지역별(3)        계        계         계         계            계
# 1   지역별(1)  지역별(2)  지역별(3)       소계       소계  자전거 전용도로  자전거 전용도로  자전거보행자 겸용도로
# 2   지역별(1)  지역별(2)  지역별(3)  노선수 (개)  길이 (km)   노선수 (개)   길이 (km)      노선수 (개)
# 3       합계      소계      소계      562    916.0        95     138.8          322
# 4       합계     도로변      소계      504    639.0        78      87.9          281
# 5       합계     도로변     종로구       22     23.7         1       4.1            6
# 6       합계     도로변      중구       13     15.4         -         -            2
# 7       합계     도로변     용산구       16     22.1         3       1.6            8
# 8       합계     도로변     성동구       22     20.6         3       0.6           10
# 9       합계     도로변     광진구       22     29.8         1       0.4           17
# 10      합계     도로변    동대문구       22     24.3         4       2.5           11
# ...

# %%
bike2 = pd.read_csv('/Users/chaewon/Desktop/서울빅캠/data/자전거 이용환경 만족도.csv')
bike2
# Out:
#     구분별(1)  구분별(2)        구분별(3)        2018      2018.1  2018.2     2018.3  \
# 0   구분별(1)  구분별(2)        구분별(3)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)
# 1      서울시      소계            소계         1.3        10.7    32.7       45.1
# 2      서울시      성별            남자         1.2        10.7    32.1       45.7
# 3      서울시      성별            여자         1.4        10.7    33.8       44.2
# 4      서울시     연령별           10대         0.7        10.8    32.9       42.3
# 5      서울시     연령별           20대         1.9        11.1    33.2       44.7
# 6      서울시     연령별           30대         1.1        10.2    32.3       46.1
# 7      서울시     연령별           40대         1.4        11.3    28.7       48.1
# 8      서울시     연령별           50대         1.7        10.4    34.2       43.6
# 9      서울시     연령별        60대 이상         0.6        10.0    36.8       43.7
# 10     서울시     학력별         중졸 이하         2.1        11.6    36.0       38.3
# ...

# %%
bike3 = pd.read_csv('/Users/chaewon/Desktop/서울빅캠/data/자전거 이용률.csv')
bike3
# Out:
#     구분별(1)  구분별(2) 2018      2018.1      2018.2   2018.3        2019  \
# 0   구분별(1)  구분별(2)   합계  이동 수단으로 이용  운동 수단으로 이용  이용하지 않음  이동 수단으로 이용
# 1      서울시      소계  100         5.5        14.9     79.7         6.6
# 2       성별      남성  100         6.9        19.9     73.2         7.5
# 3       성별      여성  100         4.2        10.1     85.7         5.8
# 4      연령별     10대  100        12.0        25.1     62.9        17.1
# ..     ...     ...  ...         ...         ...      ...         ...
# 59  지역소분류별     강동구  100         2.9         7.2     90.0         5.2
# 60    직업분류   관리전문직    -           -           -        -           -
# 61    직업분류   화이트칼라    -           -           -        -           -
# 62    직업분류    블루칼라    -           -           -        -           -
# 63    직업분류      기타    -           -           -        -           -
#
#         2019.1   2019.2   2022   2022.1    2022.2 2022.3   2022.4
# 0   운동 수단으로 이용  이용하지 않음  통학/통근  대중교통 환승  근거리 교통수단    레저용  이용하지 않음
# ...

# %%
bike4 = pd.read_csv("/Users/chaewon/Desktop/서울빅캠/data/자전거 교통사고 통계.csv")
bike4
# Out:
#     자치구별(1)  자치구별(2)     유형별(1)      2018    2018.1    2018.2      2019  \
# 0   자치구별(1)  자치구별(2)     유형별(1)  발생건수 (건)  사망자수 (명)  부상자수 (명)  발생건수 (건)
# 1        합계       소계  자전거 가해자사고      1471        18      1573      1766
# 2        합계       소계  자전거 피해자사고      1447        11      1513      1599
# 3        합계      종로구  자전거 가해자사고        21         -        22        19
# 4        합계      종로구  자전거 피해자사고        19         -        19        22
# 5        합계       중구  자전거 가해자사고        14         1        13        23
# 6        합계       중구  자전거 피해자사고        13         -        13        17
# 7        합계      용산구  자전거 가해자사고        26         -        34        22
# 8        합계      용산구  자전거 피해자사고        30         1        35        31
# 9        합계      성동구  자전거 가해자사고        47         1        51        63
# 10       합계      성동구  자전거 피해자사고        69         1        72        70
# 11       합계      광진구  자전거 가해자사고        70         2        72        61
# ...

# %%
bike5 = pd.read_csv("/Users/chaewon/Desktop/서울빅캠/data/서울시 자전거 주차시설 현황 통계.csv")
bike5
# Out:
#      시점 자전거 주차장 자전거 주차장.1 자전거 보관함 자전거 보관함.1 자전거 거치대 자전거 거치대.1
# 0    시점  지점(개소)   거치대수(대)  지점(개소)   거치대수(대)  지점(개소)   거치대수(대)
# 1  2018      23      5770      13       299    5201    140602
# 2  2019      24      5574      11       260    5209    139550
# 3  2020      28      5520      10       250    4816    125051
# 4  2021      30      5652       8       190    4778    125214
# 5  2022      31      5483       8       190    4667    121353

# %%
bike6 = pd.read_csv('/Users/chaewon/Desktop/서울빅캠/data/대여소별 이용정보1_6.csv', encoding = 'cp949')
bike6
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/chaewon/Desktop/서울빅캠/bigdata_campus-1/Bicycle/1.ipynb 셀 14 line 1
# ----> <a href='vscode-notebook-cell:/Users/chaewon/Desktop/%EC%84%9C%EC%9A%B8%EB%B9%85%EC%BA%A0/bigdata_campus-1/Bicycle/1.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> bike6 = pd.read_csv('/Users/chaewon/Desktop/서울빅캠/data/대여소별 이용정보1_6.csv', encoding = 'cp949')
#       <a href='vscode-notebook-cell:/Users/chaewon/Desktop/%EC%84%9C%EC%9A%B8%EB%B9%85%EC%BA%A0/bigdata_campus-1/Bicycle/1.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> bike6
#
# ...
